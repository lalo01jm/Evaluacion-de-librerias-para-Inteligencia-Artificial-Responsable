# %%
# %pip install -r requirements.txt
# Out:
# ...
#   Using cached numpy-2.4.6-cp311-cp311-win_amd64.whl (12.6 MB)
# ...
#      ---------------------------------------- 9.9/9.9 MB 12.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 8.3/8.3 MB 12.0 MB/s eta 0:00:00
# ...
#      -------------------------------------- 101.7/101.7 MB 9.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 932.3/932.3 kB 9.9 MB/s eta 0:00:00
# ...
#      ------------------------------------ 135.5/135.5 kB 803.0 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 9.3/9.3 MB 16.5 MB/s eta 0:00:00
# ...
#      -------------------------------------- 294.9/294.9 kB 6.1 MB/s eta 0:00:00
# ...
#      --------------------------------------- 14.6/14.6 MB 13.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 78.3/78.3 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 349.3/349.3 kB ? eta 0:00:00
# ...
#   Using cached scipy-1.17.1-cp311-cp311-win_amd64.whl (36.6 MB)
# ...
#   Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# ...
